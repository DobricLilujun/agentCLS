# %% [markdown]
# # Prompt generation using ChatGPT

# %%
# Generate a base prompt from the description
import pandas as pd
import sys
import os
import openai
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from utils.prompts import prompt_template_description_dict, META_PROMPT, prompt_template_COT_dict

for k,v in prompt_template_description_dict.items():
    print(f"Key: {k}")
    print(f"Value: {v}")
# Out:
# Key: instructions
# Value: Your task is to update a well-structured provided prompt for a text classification task based on category descriptions. Ensure clarity and precision in the prompt so the language model can accurately classify the input. Incorporate category descriptions to guide the classification process effectively. Maintain a structured format to enhance understanding and consistency. Keep original '{input}' string at the end in the generated prompt.
# Key: additional_details
# Value:
# Category Descriptions:
#  {labels_description}
# Key: output_format
# Value: The output should be a JSON format with the updated prompt and the refinement reason.
# Key: examples
# Value: {"updated_prompt": "content of updated prompt", "reason": "reason for the refinement"}

# %%
import json

with open(".vscode/.openai_api_token", "r") as file:
    api_key = file.read().strip()  # Remove any extra spaces or newlines
    
client = openai.OpenAI(api_key = api_key)

# Call the chatGPT API to generate a prompt from the description
def generate_prompt_from_description(data_path, samples=2):
    # Load the data from the JSON file
    data = pd.read_json(data_path, lines=True)
    example_data = data.groupby("cls_label").sample(samples)

    # Ensure the necessary columns exist
    if "cls_label" not in example_data.columns or "description" not in example_data.columns:
        raise ValueError("The input data must contain 'label' and 'description' columns.")
    
    labels_description = ""
    init_prompt = "Please classify the following input text into the appropriate category:\n\n {input}"
    for idx, row in example_data.iterrows():
        label = row["cls_label"]
        description = row["description"]
        example_content = row["content"]
        labels_description += f"Label: {label}\nDescription: {description}\n"

    previous_prompt = init_prompt
    gpt_prompt = META_PROMPT.format(
        instructions=prompt_template_description_dict["instructions"], 
        additional_details=prompt_template_description_dict["additional_details"].format(labels_description = labels_description),
        previous_prompt = previous_prompt,
        output_format=prompt_template_description_dict["output_format"],
        examples = prompt_template_description_dict["examples"]
        )
    response = client.chat.completions.create(
        model="gpt-4-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": gpt_prompt}
        ],
        temperature=0.7,
    )

    content = response.choices[0].message.content  # This is a JSON string
    content_dict = json.loads(content)

    return content_dict


def save_to_jsonl(content_dict, filename="output.jsonl"):
    with open(filename, "a", encoding="utf-8") as f:
        f.write(json.dumps(content_dict, ensure_ascii=False) + "\n")


input_datasets_path = "assets/LDD_split.json"
content_dict = generate_prompt_from_description(input_datasets_path)
output_file_name = f"utils/prompt_database/{input_datasets_path.split('/')[-1].split('.')[0]}_prompt_from_description.jsonl"
save_to_jsonl(content_dict, output_file_name)
print(f"Prompt saved to {output_file_name}")
print(f"Prompt generated: {content_dict['updated_prompt']}")
# Out:
# Prompt saved to utils/prompt_database/LDD_split_prompt_from_description.jsonl
# Prompt generated: To accurately classify the input text, first understand its content and context, then match it to the most appropriate category based on the descriptions provided below:
#
# - **cs.AI**: Involves topics related to Artificial Intelligence.
# - **cs.CE**: Related to Computational Engineering.
# - **cs.CV**: Pertains to Computer Vision.
# - **cs.DS**: Concerns Data Structures.
# - **cs.IT**: Deals with Information Theory.
# - **cs.NE**: Focuses on Neural and Evolutionary Computing.
# - **cs.PL**: Involves Programming Languages.
# - **cs.SY**: Related to Systems and Control.
# - **math.AC**: Pertains to Commutative Algebra.
# - **math.GR**: Involves Group Theory.
# - **math.ST**: Related to Statistics Theory.
#
# Please classify the following input text into the appropriate category based on the descriptions above:
#
# {input}

# %% [markdown]
# ## Generate a COT prompt from the data examples

# %%
import json
from utils.prompts import prompt_template_description_dict, META_PROMPT, prompt_template_COT_dict

with open(".vscode/.openai_api_token", "r") as file:
    api_key = file.read().strip()  # Remove any extra spaces or newlines
    
client = openai.OpenAI(api_key = api_key)

# Call the chatGPT API to generate a prompt from the description
def generate_COT_prompt_from_description(data_path, samples=2):
    # Load the data from the JSON file
    data = pd.read_json(data_path, lines=True)
    example_data = data.groupby("cls_label").sample(samples)

    # Ensure the necessary columns exist
    if "cls_label" not in example_data.columns or "description" not in example_data.columns:
        raise ValueError("The input data must contain 'label' and 'description' columns.")
    
    labels_description = ""
    init_prompt = "Please classify the following input text into the appropriate category:\n\n {input}"
    previous_prompt = init_prompt
    for idx, row in example_data.iterrows():
        label = row["cls_label"]
        description = row["description"]
        example_content = row["content"]
        labels_description += f"Label: {label}\nDescription: {description}\n\n"

        gpt_prompt = META_PROMPT.format(
            instructions=prompt_template_COT_dict["instructions"], 
            additional_details=prompt_template_COT_dict["additional_details"].format(labels_description = labels_description),
            previous_prompt = previous_prompt,
            output_format=prompt_template_COT_dict["output_format"],
            examples = prompt_template_COT_dict["examples"]
            )
        response = client.chat.completions.create(
            model="gpt-4-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": gpt_prompt}
            ],
            temperature=0.7,
        )

        content = response.choices[0].message.content  # This is a JSON string
        content = content.replace("```","")
        content = content.replace("json","")
        content_dict = json.loads(content)
        previous_prompt = content_dict["updated_prompt"]

    return content_dict


def save_to_jsonl(content_dict, filename="output.jsonl"):
    with open(filename, "a", encoding="utf-8") as f:
        f.write(json.dumps(content_dict, ensure_ascii=False) + "\n")


input_datasets_path = "assets/LDD_split.json"
content_dict = generate_COT_prompt_from_description(input_datasets_path,2)
output_file_name = f"utils/prompt_database/{input_datasets_path.split('/')[-1].split('.')[0]}_COT_prompt_from_description.jsonl"
save_to_jsonl(content_dict, output_file_name)
print(f"Prompt saved to {output_file_name}")
print(f"Prompt generated: {content_dict['updated_prompt']}")
# Out:
# Prompt saved to utils/prompt_database/LDD_split_COT_prompt_from_description.jsonl
# Prompt generated: To ensure accurate classification of the input text into the appropriate category, follow these structured reasoning steps:
# 1. **Analyze Input Text**: Begin by closely examining the input text. Identify key ideas and specific terminologies that relate closely to the categories listed below. Pay attention to unique concepts or phrases indicative of particular fields.
# 2. **Review Category Descriptions**: Read and understand the scope and focus of each category. Here are the descriptions to guide you:
#    - 'cs.AI': Focuses on Artificial Intelligence, involving algorithms, machine learning techniques, and AI applications.
#    - 'cs.CE': Encompasses Computational Engineering, including simulations, system design, and computational methods in engineering.
#    - 'cs.CV': Pertains to Computer Vision, dealing with image recognition, processing, and computer-based visual tasks.
#    - 'cs.DS': Involves Data Structures, emphasizing data organization, management, and storage structures.
#    - 'cs.IT': Related to Information Theory, covering data transmission, encoding, and compression methodologies.
#    - 'cs.NE': Deals with Neural and Evolutionary Computing, focusing on neural networks, genetic algorithms, and adaptive systems.
#    - 'cs.PL': Concerns Programming Languages, including syntax, semantics, and language design.
#    - 'cs.SY': Relates to Systems and Control, focusing on control systems, automation, and system dynamics.
#    - 'math.AC': Involves Commutative Algebra, dealing with rings, modules, and algebraic structures.
#    - 'math.GR': Pertains to Group Theory, focusing on mathematical groups, symmetries, and group structures.
#    - 'math.ST': Deals with Statistics Theory, focusing on statistical methods and applications.
# 3. **Match Themes with Categories**: Compare the identified themes and terminologies from the input text with the provided category descriptions. Evaluate which category aligns best with the content of the text.
# 4. **Classify and Justify**: Conclude by categorizing the text into the most fitting category based on your analysis. Provide a detailed justification for your choice, explaining how the themes and terminologies from the text align with the category's focus.
#
# Input text: {input}

# %% [markdown]
# ## Generate a Few Shot Prompt from the data examples

# %%
import json
from utils.prompts import prompt_template_few_shot_dict
# Generate a base prompt from the description
import pandas as pd
import sys
import os
import openai
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from utils.prompts import prompt_template_description_dict, META_PROMPT, prompt_template_COT_dict, META_PROMPT_JSON_FREE


with open(".vscode/.openai_api_token", "r") as file:
    api_key = file.read().strip()  # Remove any extra spaces or newlines
    
client = openai.OpenAI(api_key = api_key)

# Call the chatGPT API to generate a prompt from the description
def generate_few_shot_prompt_from_description(data_path, samples=2):
    # Load the data from the JSON file
    data = pd.read_json(data_path, lines=True)
    example_data = data.groupby("cls_label").sample(samples)

    # Ensure the necessary columns exist
    if "cls_label" not in example_data.columns or "description" not in example_data.columns:
        raise ValueError("The input data must contain 'label' and 'description' columns.")
    
    labels_description = ""
    init_prompt = "Please classify the following input text into the appropriate category:\n\n {input}"
    previous_prompt = init_prompt
    i = 0
    for idx, row in example_data.iterrows():
        label = row["cls_label"]
        description = row["description"]
        example_content = row["content"]
        summ_prompt = f"Please summarize the following content in 200 words:\n\n{example_content}"

        summarized_content = client.chat.completions.create(
            model="gpt-4-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": summ_prompt}
            ],
            temperature=0.7,
        ).choices[0].message.content

        labels_description += f"Label {i}: {label}\nDescription {i}: {description}\nContent {i}: {summarized_content}\n\n"
        i+=1
        
    gpt_prompt = META_PROMPT_JSON_FREE.format(
        instructions=prompt_template_few_shot_dict["instructions"], 
        additional_details=prompt_template_few_shot_dict["additional_details"].format(labels_description = labels_description),
        previous_prompt = previous_prompt,
        output_format=prompt_template_few_shot_dict["output_format"]
        )
    response = client.chat.completions.create(
        model="gpt-4-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": gpt_prompt}
        ],
        temperature=0.7,
    )

    content = response.choices[0].message.content  # This is a JSON string
    previous_prompt = content
    print (previous_prompt)
    return content


def save_to_jsonl(content_dict, filename="output.jsonl"):
    with open(filename, "a", encoding="utf-8") as f:
        f.write(json.dumps(content_dict, ensure_ascii=False) + "\n")


input_datasets_path = "assets/LDD_split.json"
content = generate_few_shot_prompt_from_description(input_datasets_path)
content_dict = {"updated_prompt": content}
output_file_name = f"utils/prompt_database/{input_datasets_path.split('/')[-1].split('.')[0]}_few_shot_prompt_from_description.jsonl"
save_to_jsonl(content_dict, output_file_name)
print(f"Prompt saved to {output_file_name}")
print(f"Prompt generated: {content_dict['updated_prompt']}")
# Out:
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The objective of this task is to classify a given text into a specific category based on its content. The categories are predefined, each associated with a specific field of study or topic. The classifier needs to analyze the content of the text and determine which category it best fits based on the descriptions provided.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** Articles, reports, or studies primarily focused on advancements, methodologies, applications, and theoretical aspects of artificial intelligence.
#
# ## Instructions for Classification:
# 1. **Read and Understand the Text:** Start by thoroughly reading the input text.
# 2. **Analyze the Content:** Evaluate the content against the category description provided. Focus on the main subject, methodologies, applications, and the field of study discussed.
# 3. **Match with Category:** Determine which category description best aligns with the content of the text.
# 4. **Classify:** After reasoning, conclude by assigning the appropriate category label to the text.
#
# ## Example for Classification:
# - **Input Text:** "The report by Peter Schüller introduces a novel automatic method for merging coreference annotations from multiple annotators into a unified gold standard, utilizing Answer Set Programming (ASP). This method is significant as it addresses the adjudication of coreference annotations by applying linguistic constraints and optimization criteria to minimize divergence from annotator decisions. The approach is formalized through two distinct ASP encodings and four objective functions to cater to various datasets."
#
#   **Reasoning:** The input discusses a novel method in the field of artificial intelligence, specifically using Answer Set Programming (ASP) to address issues in coreference annotations within NLP. It focuses on methodology, application, and theoretical aspects typical of AI research.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category based on the instructions and example provided:
#
#  `{input}`
#
# ## Output Format:
# - The output should be a category label (e.g., cs.AI).
# - The classification should be presented as a single label string immediately following the analysis.
#
# This prompt structure ensures clarity in task execution, guiding the language model through a systematic analysis to accurate classification, preserving the integrity of the user-provided content.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The goal here is to classify textual data accurately into a specific category based on its content, following a structured approach. Each category is clearly defined by its focus on specific areas within a broader field of study.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category includes texts that focus on the development, methods, applications, and theoretical aspects of artificial intelligence. Typical subjects may involve machine learning techniques, AI applications in real-world scenarios, theoretical AI models, and studies on AI advancements.
#
# ## Instructions for Classification:
# 1. **Read the Text:** Begin by carefully reading the provided text to understand its primary focus and details.
# 2. **Analyze the Content:** Compare and contrast the main ideas, methods, and applications discussed in the text with those outlined in the category description.
# 3. **Match with Category:** Identify the category whose description aligns most closely with the text's content.
# 4. **Classify:** Conclude by assigning the most fitting category label based on your analysis.
#
# ## Example for Classification:
# - **Input Text:** "Real-time On-Demand Crowd-powered Entity Extraction (Supplementary Technical Report) by Ting-Hao (Kenneth) Huang, Yun-Nung (Vivian) Chen, Jeffrey P. Bigham discusses a crowd-powered approach to entity extraction in dialogue systems. The method uses a multiplayer Dialog ESP Game to identify entities, enhancing extraction accuracy without pre-existing data. The study demonstrates the application of crowdsourcing in AI for real-time systems."
#
#   **Reasoning:** The text introduces a unique approach to entity extraction using crowdsourcing, a method tethered deeply to artificial intelligence due to its reliance on human-AI interaction and real-time data processing. It emphasizes AI methodologies, applications, and practical implications in dialogue systems, aligning well with the AI category focus.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category based on the instructions and example provided:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** A category label, such as `cs.AI`.
# - **Presentation:** The classification result should be presented as a label immediately following the completion of the analysis, ensuring clarity and directness in response.
#
# This revised prompt structure enhances task clarity, guiding the language model through a systematic process to achieve accurate and consistent text classification, while maintaining the integrity and completeness of the user-provided content.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The task involves classifying textual content into predefined categories based on detailed descriptions associated with each category. The goal is to achieve high accuracy by aligning the content of the text closely with the attributes and themes described in the category descriptions.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category encompasses texts that delve into various aspects of artificial intelligence, including but not limited to development, methodologies, applications, and theoretical foundations. Topics typically covered include machine learning techniques, AI in practical scenarios, theoretical models of AI, and emerging AI technologies.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Includes texts focused on the application of computational methods to engineering problems. This includes modeling, simulation, and analysis of engineering systems using computational techniques and tools, and may cover areas like finite element analysis, computational fluid dynamics, and software tools designed for engineering applications.
#
# ## Instructions for Classification:
# 1. **Read the Text:** Start by thoroughly reading the input text to grasp its primary focus, methodology, and the context in which the content is presented.
# 2. **Analyze the Content:** Evaluate the main themes, technical methods, and the field of application discussed in the text. Compare these elements against the detailed category descriptions provided.
# 3. **Match with Category:** Determine which category description best aligns with the key aspects of the text. Consider both the explicit content and underlying themes of the text.
# 4. **Classify:** Conclude your analysis by assigning the most appropriate category label, ensuring that the reasoning behind this classification is clear and well-supported by the text's content.
#
# ## Example for Classification:
# - **Input Text:** "The report by Peter Schüller introduces a novel method for merging coreference annotations using Answer Set Programming, a technique deeply rooted in artificial intelligence, aiming to optimize adjudication results in linguistic tasks."
#
#   **Reasoning:** The text discusses a method involving Answer Set Programming for optimizing linguistic tasks, a subject that falls squarely within the realm of artificial intelligence. The focus on AI methodologies and their application in linguistic analysis aligns closely with the descriptions provided for the AI category.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category based on the detailed instructions and example provided:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** A category label, such as `cs.AI`.
# - **Presentation:** The classification result should be presented clearly as a label immediately following a reasoned analysis, reflecting a structured and methodical approach to decision-making.
#
# This revised prompt structure ensures enhanced clarity and guidance for the language model, facilitating a systematic and accurate classification process while preserving the integrity of the user-provided content and guidelines.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The task involves classifying textual content into predefined categories based on detailed descriptions associated with each category. The goal is to achieve high accuracy by aligning the content of the text closely with the attributes and themes described in the category descriptions.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category includes texts that focus on the development, methodologies, applications, and theoretical foundations of artificial intelligence. Typical topics covered are machine learning techniques, AI in practical scenarios, theoretical models of AI, and emerging AI technologies.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** This category includes texts focused on the application of computational methods to engineering problems. It covers modeling, simulation, and analysis of engineering systems using computational techniques and tools, and may include areas like finite element analysis, computational fluid dynamics, and software tools designed for engineering applications.
#
# ## Instructions for Classification:
# 1. **Read the Text:** Begin by thoroughly reading the input text to understand its primary focus, methodology, and the context in which the content is presented.
# 2. **Analyze the Content:** Examine the main themes, technical methods, and the field of application discussed in the text. Compare these elements against the detailed category descriptions provided.
# 3. **Match with Category:** Determine which category description best aligns with the key aspects of the text. Consider both the explicit content and underlying themes of the text.
# 4. **Classify:** Conclude your analysis by assigning the most appropriate category label, ensuring that the reasoning behind this classification is clear and well-supported by the text's content.
#
# ## Example for Classification:
# - **Input Text:** "The report by Peter Schüller introduces a novel method for merging coreference annotations using Answer Set Programming, a technique deeply rooted in artificial intelligence, aiming to optimize adjudication results in linguistic tasks."
#
#   **Reasoning:** The text discusses a method involving Answer Set Programming for optimizing linguistic tasks, a subject that falls squarely within the realm of artificial intelligence. The focus on AI methodologies and their application in linguistic analysis aligns closely with the descriptions provided for the AI category.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category based on the detailed instructions and example provided:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** A category label, such as `cs.AI`.
# - **Presentation:** The classification result should be presented clearly as a label immediately following a reasoned analysis, reflecting a structured and methodical approach to decision-making.
#
# This refined prompt structure ensures enhanced clarity and guidance for the language model, facilitating a systematic and accurate classification process while preserving the integrity of the user-provided content and guidelines.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The task requires classifying textual content into predefined categories, each with specific descriptions that align with different domains of study. The objective is to ensure high accuracy by matching the content of the text accurately with the attributes and themes outlined in the category descriptions.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category encompasses texts that discuss the development, methodologies, applications, and theoretical foundations of artificial intelligence. Examples include machine learning algorithms, AI in practical applications, theoretical AI models, and innovative AI technologies.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** This category covers texts that address computational methods applied to engineering challenges. It includes discussions on modeling, simulation, and analysis of engineering systems through computational approaches, and might touch upon topics such as finite element analysis and computational fluid dynamics.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** This category includes texts related to technologies and methodologies in the field of computer vision. Examples might include image and video analysis, machine vision technologies, and pattern recognition techniques.
#
# ## Instructions for Classification:
# 1. **Read the Text:** Start by thoroughly reading the input text to fully understand its main focus, methodologies, and context.
# 2. **Analyze the Content:** Identify the primary themes, technical methods, and application domains discussed in the text. Compare these against the detailed descriptions in each category.
# 3. **Match with Category:** Choose the category whose description best matches the key elements of the text, considering both explicit content and implicit themes.
# 4. **Classify:** Conclude with your classification decision by assigning the most fitting category label, justifying your choice with clear, well-supported reasoning based on the text's content.
#
# ## Example for Classification:
# - **Input Text:** "This technical report discusses a new crowd-powered method for real-time entity extraction in dialogue systems, leveraging multiplayer gaming mechanics for better accuracy in identifying entities."
#
#   **Reasoning:** The text introduces a technique using crowd-sourced information processing for entity extraction in real-time, an innovative application within the realm of artificial intelligence. The focus on leveraging human input for improving machine processing tasks aligns with the AI category's emphasis on novel AI technologies and methodologies.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category based on the detailed instructions and example provided:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** A category label, such as `cs.AI`.
# - **Presentation:** Present the classification result as a label, preceded by a reasoned analysis, demonstrating a systematic and thoughtful approach to the classification.
#
# This refined prompt structure offers enhanced clarity and detailed guidance for the language model, ensuring a systematic and accurate classification process while adhering strictly to user-provided content and guidelines.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# This task involves classifying textual content into specific categories based on detailed descriptions corresponding to different academic and professional domains. The primary goal is to ensure accurate classification by carefully aligning the content of the input text with the thematic and technical elements outlined in the category descriptions.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** Includes discussions and innovations concerning artificial intelligence, such as methodologies, theoretical models, practical applications, and new technologies in AI.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Focuses on computational methods used in engineering, including simulations, system modeling, and analyses using computational techniques.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Encompasses technologies and methods in computer vision, including image and video analysis, pattern recognition, and machine vision technologies.
#
# ## Instructions for Classification:
# 1. **Read the Input Text:** Begin by thoroughly reading the input text to grasp its main ideas, methods, and context.
# 2. **Analyze the Content:** Identify key themes, technical approaches, and discussed applications. Compare these elements against the detailed category descriptions provided.
# 3. **Reasoning Before Conclusion:** Based on the comparison, reason out why the text should belong to a particular category by linking its main elements to those described in the category.
# 4. **Classify:** End with a classification decision. Assign the category label that best matches the input text, providing a clear justification for this choice based on the text's alignment with the category's description.
#
# ## Example for Classification:
# - **Input Text:** "This technical report elaborates on a multiplayer game-based, crowd-powered approach for real-time entity extraction in dialogue systems, aiming to enhance accuracy in entity identification."
#
#   **Reasoning:** The text introduces a method that employs crowd-sourced data processing for real-time entity extraction in dialogue systems, leveraging innovative AI techniques. The emphasis on using human input to improve machine processing tasks is characteristic of the artificial intelligence field, particularly within innovative AI technologies and methodologies.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category using the detailed instructions and example provided for guidance:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** A category label, such as `cs.AI`.
# - **Presentation:** Present the classification result as a label, followed by a reasoned analysis, demonstrating a systematic and thoughtful approach to the classification process.
#
# This revised prompt structure enhances clarity and provides detailed guidance, ensuring a systematic and accurate classification process. It adheres strictly to user-provided content and guidelines, fostering a structured approach to textual classification.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The objective of this task is to classify textual content into specified categories based on their academic or professional themes. Each category has been described in detail to aid in accurate classification. The goal is to align the thematic and technical elements of the content with the corresponding category descriptions provided.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category includes content related to artificial intelligence, such as discussions on methodologies, theoretical models, practical applications, and innovations in AI technologies.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** This category covers computational methods in engineering, focusing on simulations, system modeling, and computational analysis techniques used in engineering applications.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** This category involves content on computer vision technologies and methods, including image and video analysis, pattern recognition, and advancements in machine vision.
#
# ## Instructions for Classification:
# 1. **Read the Input Text:** Carefully read the provided text to understand its primary ideas, methods, and contextual details.
# 2. **Analyze the Content:** Identify and highlight the main themes, technical approaches, and applications discussed in the text. Compare these elements with those specified in the category descriptions.
# 3. **Reasoning Before Conclusion:** Reason out why the text fits into a particular category by correlating its main elements with those outlined in the category description.
# 4. **Classify the Text:** Conclude with a classification decision. Assign a category label that most accurately reflects the content of the text, providing a detailed justification based on its alignment with the category's described attributes.
#
# ## Example for Classification:
# - **Input Text:** "The report explores a novel method for merging coreference annotations using Answer Set Programming, which significantly enhances the adjudication process in linguistic datasets."
#
#   **Reasoning:** The text discusses a novel AI method applied to linguistic datasets, focusing on enhancing coreference resolution processes. This method, which uses Answer Set Programming, aligns with advancements and innovative applications in artificial intelligence as it relates to processing linguistic data effectively.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category using the detailed instructions and example provided for guidance:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** Provide the category label (e.g., `cs.AI`) followed by a reasoned analysis.
# - **Presentation:** The classification result should be presented clearly, illustrating a logical and systematic approach to the classification process.
#
# This prompt maintains a structured approach and enhances clarity for the classification task, ensuring accuracy and alignment with user-provided content and guidelines. The instructions are detailed and guide the user step-by-step through the classification process, emphasizing reasoning before drawing conclusions.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The objective of this task is to classify textual content into specific academic or professional categories based on detailed descriptions provided for each category. The classifier should match the thematic, theoretical, and methodological elements of the content with the appropriate category, ensuring a precise and reasoned classification.
#
# ## Category Descriptions and Guidelines:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** Content categorized here involves discussions on AI methodologies, theoretical AI models, practical AI applications, and innovations in AI technologies. This includes studies on machine learning, neural networks, AI-based optimization, and applications in various domains like NLP and robotics.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** This category encompasses computational methods used in engineering practices. It includes content on simulations, system modeling, numerical analysis, and computational techniques aimed at solving complex engineering problems.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Content in this category deals with technologies and methods in computer vision. This includes image and video analysis, pattern recognition, algorithms for object and facial recognition, and advancements in automated visual understanding.
#
# ## Instructions for Classification:
# 1. **Read the Input Text:** Carefully examine the provided text to grasp its primary ideas, methods, and contextual details.
# 2. **Analyze the Content:** Identify the main themes, technical approaches, and applications discussed. Pay attention to specific methodologies, tools, or theoretical concepts mentioned in the text.
# 3. **Reasoning Before Conclusion:** Before concluding, reason out why the text should be categorized under a specific label by directly correlating its content with the attributes outlined in the corresponding category description.
# 4. **Classify the Text:** Provide a reasoned classification decision. Assign the category label that most accurately reflects the content of the text, supporting your decision with a detailed justification based on its alignment with the category’s characteristics.
#
# ## Example for Classification:
# - **Input Text:** "This study presents a new gradient descent approach optimized for quantum control systems, addressing challenges in maintaining quantum state during measurements."
#
#   **Reasoning:** The text introduces a computational method (gradient descent) tailored for engineering applications in quantum systems, a niche within computational engineering. It discusses optimization of control systems, a common theme in computational engineering, especially with the specific challenge of quantum state measurements.
#
#   **Classification:** cs.CE
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category using the detailed instructions and example provided for guidance:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** Start with the category label (e.g., `cs.AI`) followed by a detailed explanation that showcases a logical and systematic approach to the classification process.
# - **Presentation:** Ensure the classification result is presented clearly, illustrating a thoughtful analysis and a step-by-step reasoning process.
#
# This prompt is structured to enhance clarity and accuracy in the classification task. It provides comprehensive instructions and examples, guiding the user systematically through each step of the classification process, with a strong emphasis on detailed reasoning before reaching conclusions.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The goal is to accurately classify textual content into designated academic categories based on comprehensive descriptions of each category. The classifier should consider thematic, theoretical, and methodological aspects of the content to ensure a correct match with the relevant category.
#
# ## Category Descriptions and Guidelines:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category includes content related to AI methodologies, theoretical models, practical applications, and technological innovations in AI. Topics covered may include machine learning, neural networks, AI-based optimization, and applications in fields such as natural language processing (NLP) and robotics.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** This category covers computational methods applied in engineering, including simulations, system modeling, numerical analysis, and computational techniques designed to address complex engineering challenges.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** This category involves methods and technologies in computer vision, such as image and video analysis, pattern recognition, algorithms for object and facial recognition, and advancements in automated visual understanding.
#
# ## Instructions for Classification:
# 1. **Read the Input Text:** Thoroughly review the text to understand its main ideas, methodologies, and contextual nuances.
# 2. **Analyze the Content:** Determine the central themes, technical approaches, and applications discussed. Note any specific methodologies, tools, or theoretical concepts mentioned.
# 3. **Reasoning Before Conclusion:** Evaluate the content against the attributes of the potential categories. Reason why the text fits a particular category based on its thematic and methodological alignment with the category description before making a final decision.
# 4. **Classify the Text:** Conclude with a reasoned classification, assigning the category label that best matches the content. Support your decision with a detailed justification based on the content's alignment with the category’s characteristics.
#
# ## Example for Classification:
# - **Input Text:** "This technical report expands on a crowd-powered real-time entity extraction system, enhancing dialogue systems by utilizing real-time responses from crowd workers to identify entities."
#
#   **Reasoning:** The text discusses an innovative application of AI in real-time systems, specifically in the context of dialogue systems and entity extraction. It incorporates AI methodologies like real-time crowdsourcing and enhances AI applications in practical settings, fitting the themes typically associated with Artificial Intelligence.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category, using the detailed instructions and example provided for guidance:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** Begin with the category label (e.g., `cs.AI`) and include a comprehensive explanation that demonstrates a logical and systematic approach to the classification process.
# - **Presentation:** Ensure the classification result is clearly presented, reflecting thorough analysis and a step-by-step reasoning process.
#
# This prompt is designed to improve clarity and accuracy in the classification task, providing extensive instructions and examples that guide the user through each step of the classification process, emphasizing detailed reasoning before reaching conclusions.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The objective is to categorize textual content accurately into specific academic categories based on detailed descriptions provided for each category. The classifier must evaluate the text's thematic content, theoretical underpinnings, and methodological approaches to ensure alignment with the appropriate category.
#
# ## Category Descriptions and Guidelines:
#
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category encompasses discussions related to AI, including but not limited to machine learning, neural networks, optimization techniques, and their applications in areas such as natural language processing (NLP) and robotics.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Articles in this category focus on the application of computational methods in engineering disciplines, featuring content on simulations, system modeling, and numerical methods used to solve complex engineering problems.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** This category deals with technologies and methodologies in computer vision, including image and video processing, pattern recognition, and development of algorithms for object and facial recognition.
#
# ## Instructions for Classification:
# 1. **Read the Input Text:** Carefully read through the provided text to grasp the primary ideas, methodologies, and context.
# 2. **Analyze the Content:** Identify the main themes, technical methods, and practical applications discussed in the text. Pay attention to specific methodologies, tools, or theoretical concepts mentioned.
# 3. **Reasoning Before Conclusion:** Compare and contrast the text's content with the characteristics of each category. Deliberate on why the text should be classified under a particular category based on its thematic and methodological congruence with the descriptions provided.
# 4. **Classify the Text:** Make a reasoned classification by assigning the category label that most closely matches the content. Support your classification with a detailed explanation that links the content to the category’s defined attributes.
#
# ## Example for Classification:
# - **Input Text:** "This technical report expands on a crowd-powered real-time entity extraction system, enhancing dialogue systems by utilizing real-time responses from crowd workers to identify entities."
#
#   **Reasoning:** The text introduces an innovative AI application that enhances real-time systems, particularly in the realm of dialogue systems and entity extraction. It integrates AI methodologies such as real-time crowdsourcing, which is aligned with typical themes in the Artificial Intelligence category.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Please classify the following input text into the appropriate category, using the detailed instructions and example provided for guidance:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** Start with the category label (e.g., `cs.AI`) followed by a comprehensive explanation that showcases a logical progression in the classification process, from analysis to conclusion.
# - **Presentation:** The classification result should be distinctly presented, demonstrating a thorough analysis and systematic reasoning process from start to finish.
#
# This prompt is crafted to enhance both clarity and precision in the classification task, providing elaborate instructions and examples that meticulously guide the user through each step, emphasizing detailed reasoning prior to concluding.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# The task involves accurately categorizing textual content into specified academic categories based on detailed descriptions. The classification process should evaluate the thematic content, theoretical background, and methodological approaches outlined in the text to ascertain its alignment with the respective category.
#
# ## Category Descriptions:
#
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category includes discussions on AI, covering areas such as machine learning, neural networks, optimization techniques, and applications in fields like natural language processing (NLP) and robotics.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Focuses on computational methods in engineering, featuring articles on simulations, system modeling, and numerical methods to address complex engineering challenges.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Pertains to computer vision technologies and methodologies, including image and video processing, pattern recognition, and algorithm development for object and facial recognition.
#
# ## Instructions for Classification:
# 1. **Read the Input Text:** Thoroughly review the provided text to understand the main concepts, methodologies, and context.
# 2. **Analyze the Content:** Identify key themes, technical methods, and practical applications discussed. Note any specific methodologies, tools, or theoretical concepts mentioned.
# 3. **Reasoning Before Conclusion:** Evaluate how the text aligns with the characteristics of each category based on thematic and methodological content. Consider why the text fits a particular category based on its content and the category descriptions.
# 4. **Classify the Text:** Based on your analysis, assign the most fitting category label to the text. Provide a detailed explanation that connects the content with the category’s defined attributes.
#
# ## Example for Classification:
# - **Input Text:** "This technical report expands on a crowd-powered real-time entity extraction system, enhancing dialogue systems by utilizing real-time responses from crowd workers to identify entities."
#
#   **Reasoning:** The text discusses an AI application focused on enhancing real-time systems, particularly in dialogue systems and entity extraction. It employs AI methodologies like real-time crowdsourcing, aligning with themes typically found in the Artificial Intelligence category.
#
#   **Classification:** cs.AI
#
# ## Final Prompt:
# Using the detailed instructions and example as guidance, please classify the following input text into the appropriate category:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** Begin with the category label (e.g., `cs.AI`) followed by a detailed rationale that demonstrates a logical progression in the classification process, from initial analysis to the final conclusion.
# - **Presentation:** Ensure that the classification result is clearly presented, showing a thorough analysis and systematic reasoning from beginning to end.
#
# This refined prompt is designed to enhance clarity and precision in the classification task, providing comprehensive instructions and examples that guide the user step-by-step, emphasizing detailed reasoning prior to reaching conclusions.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# This task requires the classification of text excerpts into specific academic categories based on their content, which includes theoretical background, methodologies, and application areas. Each text must be accurately categorized according to predefined academic labels.
#
# ## Category Descriptions:
#
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category includes discussions on AI, encompassing areas such as machine learning, neural networks, optimization techniques, and real-world applications in fields like natural language processing (NLP) and robotics.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Articles under this label deal with computational methods used in engineering, including simulations, system modeling, and numerical methods designed to solve complex engineering problems.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Focuses on technologies and methods related to computer vision such as image and video processing, pattern recognition, and development of algorithms for object and facial recognition.
#
# ## Classification Instructions:
# 1. **Read the Input Text:** Thoroughly review the provided text, focusing on its main concepts, methodologies, and contextual applications.
# 2. **Analyze Key Themes and Methods:** Identify and highlight the primary themes, technical methods, and any specific tools or theoretical concepts mentioned in the text.
# 3. **Reasoning Before Conclusion:** Before concluding, assess how the text's content aligns with the characteristics of each category. Evaluate the relevance of the text's themes and methodologies to the category descriptions.
# 4. **Classify the Text:** Choose the category that best matches the content of the text. Provide a well-reasoned explanation that connects the text’s content with the attributes of the chosen category.
#
# ## Example for Classification:
# - **Input Text:** "This technical report expands on a crowd-powered real-time entity extraction system, enhancing dialogue systems by utilizing real-time responses from crowd workers to identify entities."
#
# - **Reasoning:** The input text discusses the application of AI in enhancing real-time systems, particularly in dialogue systems and entity extraction, using crowd-sourced real-time data. This aligns with typical themes found in the Artificial Intelligence category, such as real-time processing and the use of AI to improve system interactions.
#
# - **Classification:** cs.AI
#
# ## Final Prompt:
# Using the structured instructions and example above, classify the following input text into the appropriate category:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** Start with the category label (e.g., `cs.AI`) followed by a detailed rationale. The rationale should trace a clear and logical progression from the initial analysis of the text to the reasoned conclusion that justifies the classification.
# - **Presentation:** Ensure that the classification and its justification are presented clearly and systematically, demonstrating a comprehensive understanding and analysis of the text from start to finish.
#
# This refined prompt enhances the clarity and precision required for the classification task, providing a detailed guide and an example that emphasize systematic reasoning from analysis to conclusion.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# You are required to classify text excerpts into specific academic categories based on their content, focusing on theoretical background, methodologies, applications, and other relevant academic aspects. Each text must be accurately categorized according to predefined academic labels.
#
# ## Category Descriptions:
#
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category encompasses discussions on AI, including areas such as machine learning, neural networks, optimization techniques, and their applications in fields like natural language processing (NLP) and robotics.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Articles in this category deal with computational methods used in engineering. This includes simulations, system modeling, and numerical methods designed to solve complex engineering problems.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Focuses on technologies and methodologies related to computer vision, such as image and video processing, pattern recognition, and development of algorithms for object and facial recognition.
#
# ## Classification Instructions:
# 1. **Read the Input Text:** Thoroughly review the provided text, focusing on its main concepts, methodologies, and contextual applications.
# 2. **Analyze Key Themes and Methods:** Identify the primary themes, technical methods, and any specific tools or theoretical concepts mentioned in the text.
# 3. **Reasoning Before Conclusion:** Assess how the text's content aligns with the characteristics of each category. Evaluate the relevance of the text's themes and methodologies to the category descriptions.
# 4. **Classify the Text:** Choose the category that best matches the content of the text. Provide a well-reasoned explanation that connects the text’s content with the attributes of the chosen category.
#
# ## Example for Classification:
# - **Input Text:** "This technical report expands on a crowd-powered real-time entity extraction system, enhancing dialogue systems by utilizing real-time responses from crowd workers to identify entities."
#
# - **Reasoning:** The input text discusses the application of AI in enhancing real-time systems, particularly in dialogue systems and entity extraction, using crowd-sourced real-time data. This aligns with typical themes found in the Artificial Intelligence category, such as real-time processing and the use of AI to improve system interactions.
#
# - **Conclusion:** cs.AI
#
# ## Final Prompt:
# Using the structured instructions and example provided, classify the following input text into the appropriate category:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** Start with the category label (e.g., `cs.AI`) followed by a detailed rationale. The rationale should trace a clear and logical progression from the initial analysis of the text to the reasoned conclusion that justifies the classification.
# - **Presentation:** Ensure that the classification and its justification are presented clearly and systematically, demonstrating a comprehensive understanding and analysis of the text from start to finish.
#
# This refined prompt enhances the clarity and precision required for the classification task, providing a detailed guide and an example that emphasize systematic reasoning from analysis to conclusion.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# You are tasked with classifying text excerpts into specific academic categories by closely examining the content regarding theoretical background, methodologies, applications, and other academic nuances. Each text must be accurately categorized based on predefined academic labels that reflect different areas of scholarly research and development.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category includes discussions on AI technologies and methodologies, such as machine learning, neural networks, optimization techniques, and their applications in fields like natural language processing (NLP) and robotics.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Articles categorized here deal with computational methods applied in engineering, including but not limited to simulations, system modeling, and numerical methods aimed at solving intricate engineering challenges.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** This category focuses on technologies and methodologies related to processing visual information, including image and video analysis, pattern recognition, and algorithm development for object and facial recognition.
#
# ## Classification Instructions:
# 1. **Read the Input Text:** Carefully read the provided text, paying special attention to its main concepts, methodologies, and the context in which these are applied.
# 2. **Analyze Key Themes and Methods:** Identify and note the primary themes, technical methods, and any specific tools or theoretical concepts mentioned within the text.
# 3. **Reasoning Before Conclusion:** Evaluate how the content of the text correlates with the characteristics of each category. Consider the relevance of the text's themes and methodologies to the descriptions provided for each category.
# 4. **Classify the Text:** Select the category that most closely reflects the content of the text. Provide a reasoned explanation that links the text’s content to the attributes of the chosen category.
#
# ## Example for Classification:
# - **Input Text:** "This technical report expands on a crowd-powered real-time entity extraction system, enhancing dialogue systems by utilizing real-time responses from crowd workers to identify entities."
#
# - **Reasoning:** The input text discusses the application of crowd-sourced, real-time data processing to enhance entity extraction capabilities in dialogue systems. This involves the strategic use of AI for processing and improving system interactions in real-time, which is a central theme in Artificial Intelligence, specifically in the context of enhancing interactive systems and processing dynamic inputs.
#
# - **Conclusion:** cs.AI
#
# ## Final Prompt:
# Using the detailed instructions and example provided, classify the following input text into the appropriate category:
#
#  `{input}`
#
# ## Output Format:
# - **Output:** Begin with the category label (e.g., `cs.AI`) followed by a thorough rationale. The rationale should demonstrate a clear, logical progression from initial text analysis to a reasoned conclusion, justifying the classification based on detailed assessment and alignment with category characteristics.
# - **Presentation:** Ensure that both the classification decision and its justification are presented in a clear, structured manner, illustrating a complete and systematic understanding and evaluation of the text from beginning to end.
#
# This refined prompt enhances clarity and precision for the text classification task, providing a structured guide and an illustrative example that underscore the importance of methodical reasoning leading to a well-supported conclusion.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Description:
# You are tasked with classifying text excerpts into specific academic categories based on their content, with a focus on theoretical frameworks, methodologies, applications, and other academic elements. Each text should be accurately categorized using predefined labels that represent distinct areas of scholarly research.
#
# ## Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category encompasses discussions on AI techniques and methodologies, including machine learning, neural networks, and optimization techniques, as well as their applications in areas such as NLP and robotics.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Texts in this category involve computational methods used in engineering, including simulations, system modeling, and numerical methods, to address complex engineering problems.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
# ...
# 3. **Reasoning Process:** Conduct a systematic analysis to determine how the themes and methods align with the characteristics of each category.
# 4. **Conclusion and Classification:** Choose the most appropriate category based on your analysis. Justify your decision by linking the content of the text explicitly to the features of the chosen category.
#
# ## Example for Classification:
# - **Input Text:** "This technical report elaborates on a novel method utilizing real-time crowd-sourced data to enhance entity extraction in dialogue systems, aiming to improve interaction efficiency."
#
# - **Analysis and Reasoning:** The text introduces a method that integrates real-time crowd-sourced data for improving entity extraction, which is pivotal in enhancing dialogue systems. The emphasis on real-time data handling and system interaction efficiency is characteristic of Artificial Intelligence applications, especially in adaptive and interactive systems.
#
# - **Conclusion:** cs.AI - The selected category is justified as the methodology and application discussed align closely with the core aspects of Artificial Intelligence, such as optimizing interactions and processing dynamic data inputs.
#
# ## Refined Few-Shot Prompt:
# Following these guidelines and using the example above as a reference, classify the given text into the correct category:
#
#  `{input}`
#
# ## Expected Output Format:
# - **Output:** Begin with the category label (e.g., `cs.AI`), followed by a detailed rationale. The rationale should progress from your initial analysis of the text to the reasoned conclusion, justifying the classification based on alignment with the category characteristics.
# - **Presentation:** Ensure the classification rationale is clear, well-structured, and demonstrates a comprehensive understanding and evaluation of the text.
#
# This refined prompt enhances the clarity and precision of the task, providing a structured guide that emphasizes the importance of methodical reasoning leading to a well-supported classification conclusion.
# # Refined Few-Shot Prompt for Text Classification Task
#
# ## Task Overview:
# Your task is to classify excerpts of academic text into specific research categories based on their content, emphasizing theoretical frameworks, methodologies, and the applications discussed. Each category has distinct characteristics that guide your decision-making process.
#
# ## Detailed Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category encompasses discussions on AI techniques such as machine learning, neural networks, optimization techniques, and their applications across diverse areas like natural language processing, robotics, and decision systems.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Focuses on computational methods in engineering tasks, including simulations, system modeling, computational mechanics, and numerical methods designed to address complex engineering problems.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Pertains to the processing of visual information, which includes image and video analysis, pattern recognition, and developing algorithms for applications such as automated surveillance and autonomous driving.
#
# ## Refined Classification Guidelines:
# 1. **Initial Reading:** Thoroughly read the provided text, focusing on the primary concepts, methodologies, and described applications.
# 2. **Identify Key Themes:** Identify essential themes, technical methods, and specific tools or theoretical concepts mentioned.
# 3. **Detailed Reasoning:** Analyze systematically how the identified themes and methods correspond with the defining characteristics of each category.
# 4. **Conclusion and Classification:** Determine the most fitting category based on your analysis. Justify your decision by explicitly linking the text content to the category's defining features.
#
# ## Example for Classification:
# - **Input Text:** "This technical report elaborates on a novel method utilizing real-time crowd-sourced data to enhance entity extraction in dialogue systems, aiming to improve interaction efficiency."
#
# - **Analysis and Reasoning:** The text introduces a method that integrates real-time crowd-sourced data for improving entity extraction, which is pivotal in enhancing dialogue systems. The emphasis on real-time data handling and system interaction efficiency is characteristic of Artificial Intelligence applications, especially in adaptive and interactive systems.
#
# - **Conclusion:** cs.AI - The selected category is justified as the methodology and application discussed align closely with the core aspects of Artificial Intelligence, such as optimizing interactions and processing dynamic data inputs.
#
# ## Few-Shot Prompt for Classification:
# Following the guidelines provided and using the example above as a reference, classify the following text into the correct category:
#
#  `{input}`
#
# ## Expected Output Format:
# - **Output:** Begin with the category label (e.g., `cs.AI`), followed by a detailed rationale. The rationale should detail your initial analysis of the text, the reasoning process, and the conclusion, justifying the classification based on alignment with the category characteristics.
# - **Presentation:** Ensure the classification rationale is clear, well-structured, and demonstrates a thorough understanding and evaluation of the text.
#
# This refined prompt improves the clarity and precision of the task, offering a structured guide that emphasizes the importance of methodical reasoning leading to a well-supported classification conclusion.
# ## Refined Few-Shot Prompt for Text Classification Task
#
# ### Task Overview:
# The objective is to categorize academic text excerpts into specified research categories based on content analysis, with a focus on the theoretical frameworks, methodologies, and applications discussed. Each category has unique features that should guide the classification process.
#
# ### Detailed Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** This category includes discussions on AI techniques (e.g., machine learning, neural networks, optimization techniques) and their applications in areas such as natural language processing, robotics, and decision systems.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Encompasses computational methods used in engineering tasks, like simulations, system modeling, computational mechanics, and numerical methods to solve complex engineering challenges.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Involves processing visual information, including image and video analysis, pattern recognition, and developing algorithms for automated surveillance, autonomous driving, and similar applications.
#
# ### Classification Guidelines:
# 1. **Initial Reading:** Carefully read the provided text, focusing on primary concepts, methodologies, and applications described.
# 2. **Identify Key Themes:** Pinpoint essential themes, technical methods, and specific tools or theoretical concepts mentioned in the text.
# 3. **Detailed Reasoning:** Systematically analyze how the identified themes and methods correspond with the defining characteristics of each research category.
# 4. **Conclusion and Classification:** Decide the most appropriate category based on your analysis. Justify your decision by clearly linking the text content to the category’s defining features.
#
# ### Example for Classification:
# - **Input Text:** "This technical report elaborates on a novel method utilizing real-time crowd-sourced data to enhance entity extraction in dialogue systems, aiming to improve interaction efficiency."
#
# - **Analysis and Reasoning:** The text discusses a method integrating real-time crowd-sourced data to enhance entity extraction in dialogue systems, focusing on improving interaction efficiency. This approach is typical of Artificial Intelligence applications, particularly in enhancing adaptive and interactive systems.
#
# - **Conclusion:** cs.AI - The selection is justified as the methodology and application align closely with the core aspects of Artificial Intelligence, emphasizing optimization of interactions and processing dynamic data inputs.
#
# ### Few-Shot Prompt for Classification:
# Following the guidelines provided and using the example above as a reference, classify the following text into the correct category:
#
#  `{input}`
#
# ### Expected Output Format:
# - **Output:** Begin with the category label (e.g., `cs.AI`), followed by a detailed rationale. The rationale should detail your initial analysis of the text, the reasoning process, and the conclusion, justifying the classification based on alignment with the category characteristics.
# - **Presentation:** Ensure the classification rationale is clear, well-structured, and demonstrates a thorough understanding and evaluation of the text.
#
# This refined prompt enhances clarity and precision in the task description, offering a structured guide that emphasizes the importance of methodical reasoning leading to a well-supported classification conclusion.
# ## Refined Few-Shot Prompt for Text Classification Task
#
# ### Task Overview:
# The goal is to classify academic excerpts into specified categories based on their content, emphasizing theoretical frameworks, methodologies, and applications discussed within each text.
#
# ### Detailed Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** Focuses on AI techniques like machine learning, neural networks, and optimization, applied in fields such as natural language processing, robotics, and decision-making systems.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Covers computational methods in engineering tasks, including simulations, system modeling, computational mechanics, and numerical methods for complex engineering challenges.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Pertains to processing visual information through image and video analysis, pattern recognition, and algorithm development for applications like automated surveillance and autonomous driving.
#
# ### Classification Guidelines:
# 1. **Initial Reading:** Thoroughly read the provided text, concentrating on primary concepts, methodologies, and applications.
# 2. **Identify Key Themes:** Identify crucial themes, methodologies, and specific tools or theoretical concepts.
# 3. **Detailed Reasoning:** Analyze how the themes and methodologies correlate with the characteristics of each category.
# 4. **Conclusion and Classification:** Determine the most fitting category based on your analysis, linking the text content to the category's defining features clearly.
#
# ### Example for Classification:
# - **Input Text:** "This technical report elaborates on a novel method utilizing real-time crowd-sourced data to enhance entity extraction in dialogue systems, aiming to improve interaction efficiency."
#
# - **Analysis and Reasoning:** The text introduces a method that integrates real-time crowd-sourced data to improve entity extraction in dialogue systems, focusing on interaction efficiency. Such an approach is characteristic of Artificial Intelligence applications, especially in enhancing adaptive and interactive systems.
#
# - **Conclusion:** cs.AI - This classification is justified as the methodology and application closely align with the core aspects of Artificial Intelligence, which focuses on optimizing interactions and processing dynamic data inputs.
#
# ### Few-Shot Prompt for Classification:
# Utilizing the guidelines above and referencing the example provided, classify the following text into the appropriate category:
#
#  `{input}`
#
# ### Expected Output Format:
# - **Output:** Start with the category label (e.g., `cs.AI`), followed by a detailed rationale. The rationale should outline your initial text analysis, the reasoning process, and the conclusion, justifying the classification based on its alignment with category characteristics.
# - **Presentation:** Ensure the rationale for classification is clear, structured, and demonstrates a comprehensive understanding and assessment of the text.
#
# This refined prompt enhances clarity and precision in the task description, offering a structured guide that emphasizes the importance of methodical analysis and reasoned conclusions in achieving an accurate classification.
# Prompt saved to utils/prompt_database/LDD_split_few_shot_prompt_from_description.jsonl
# Prompt generated: ## Refined Few-Shot Prompt for Text Classification Task
#
# ### Task Overview:
# The goal is to classify academic excerpts into specified categories based on their content, emphasizing theoretical frameworks, methodologies, and applications discussed within each text.
#
# ### Detailed Category Descriptions:
# - **Label:** cs.AI
#   **Description:** Artificial Intelligence
#   **Content:** Focuses on AI techniques like machine learning, neural networks, and optimization, applied in fields such as natural language processing, robotics, and decision-making systems.
#
# - **Label:** cs.CE
#   **Description:** Computational Engineering
#   **Content:** Covers computational methods in engineering tasks, including simulations, system modeling, computational mechanics, and numerical methods for complex engineering challenges.
#
# - **Label:** cs.CV
#   **Description:** Computer Vision
#   **Content:** Pertains to processing visual information through image and video analysis, pattern recognition, and algorithm development for applications like automated surveillance and autonomous driving.
#
# ### Classification Guidelines:
# 1. **Initial Reading:** Thoroughly read the provided text, concentrating on primary concepts, methodologies, and applications.
# 2. **Identify Key Themes:** Identify crucial themes, methodologies, and specific tools or theoretical concepts.
# 3. **Detailed Reasoning:** Analyze how the themes and methodologies correlate with the characteristics of each category.
# 4. **Conclusion and Classification:** Determine the most fitting category based on your analysis, linking the text content to the category's defining features clearly.
#
# ### Example for Classification:
# - **Input Text:** "This technical report elaborates on a novel method utilizing real-time crowd-sourced data to enhance entity extraction in dialogue systems, aiming to improve interaction efficiency."
#
# - **Analysis and Reasoning:** The text introduces a method that integrates real-time crowd-sourced data to improve entity extraction in dialogue systems, focusing on interaction efficiency. Such an approach is characteristic of Artificial Intelligence applications, especially in enhancing adaptive and interactive systems.
#
# - **Conclusion:** cs.AI - This classification is justified as the methodology and application closely align with the core aspects of Artificial Intelligence, which focuses on optimizing interactions and processing dynamic data inputs.
#
# ### Few-Shot Prompt for Classification:
# Utilizing the guidelines above and referencing the example provided, classify the following text into the appropriate category:
#
#  `{input}`
#
# ### Expected Output Format:
# - **Output:** Start with the category label (e.g., `cs.AI`), followed by a detailed rationale. The rationale should outline your initial text analysis, the reasoning process, and the conclusion, justifying the classification based on its alignment with category characteristics.
# - **Presentation:** Ensure the rationale for classification is clear, structured, and demonstrates a comprehensive understanding and assessment of the text.
#
# This refined prompt enhances clarity and precision in the task description, offering a structured guide that emphasizes the importance of methodical analysis and reasoned conclusions in achieving an accurate classification.
